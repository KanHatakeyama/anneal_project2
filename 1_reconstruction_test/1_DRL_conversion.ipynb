# %% [markdown]
# # Data reconstruction by DRL
# - Convert molecular information into binary by molecular fingerprint, and restore it by DRL
#     - Molecular fingerprint: Avalon fingerprint
#     - DRL: REINVENT 2.0

# %%
import glob
import os
import sys
import joblib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from rdkit import Chem

sys.path.append("../lib")
from fp_func import fp_func, fp_similarity

sys.path.append("../REINVENT/lib/")
from train_agent import train_agent
# Out:
# RDKit WARNING: [16:49:36] Enabling RDKit 2019.09.3 jupyter extensions

# %%
#load random 150 molecules from Bradley's dataset
file_path="../database/random_smiles.csv"
df=pd.read_csv(file_path)
smiles_list=list(df["SMILES"].values)
smiles_list[:3]
# Out:
# ['c1ccc2c(c1)nc(s2)N',
#  'c1ccc(cc1)COC(=O)/C=C/c2ccccc2',
#  'O=C1C=C(C)C(=O)C(C)=C1']

# %%
# DRL
def reconstruct(smiles):
    
    #calc fingerprint (fp)
    
    mol = Chem.MolFromSmiles(smiles)

    if os.getcwd().split("/")[-1] != "REINVENT":
        os.chdir('../REINVENT/')

    fp = fp_func(mol)
    fp = [str(i) for i in fp]
    fp = "".join(fp)

    #settings for DRL
    arg_dict = {
        "scoring_function": "fp_similarity",
        "scoring_function_kwargs": {
            "query_bit": fp,
        },
        "n_steps": 300,
        "verbose": False
    }

    # run
    train_agent(**arg_dict)

    os.chdir('../1_reconstruction_test')

    # analyze
    result_path = sorted(glob.glob("../REINVENT/data/results/*"))[-1]+"/memory"
    dqn_df = pd.read_csv(result_path, delimiter=" ")
    best_smiles = list(dqn_df.sort_values(
        ["Score", "PriorLogP"], ascending=False)[0:1]["SMILES"])[0]

    return best_smiles

# %%
from tqdm.notebook import tqdm
reconst_sm_list=[]

#loop
for sm1 in tqdm(smiles_list):
    try:
        sm2=reconstruct(sm1)
    except:
        sm2="C"
    reconst_sm_list.append(sm2)
    
    #joblib.dump(reconst_sm_list,"dqn_smiles_temp.bin")
    break
# Out:
#   0%|          | 0/150 [00:00<?, ?it/s]
# cuda:1
# Model initialized, starting training...
#
# Best score in memory: 0.57
#
# Best score in memory: 0.57
#
# Best score in memory: 0.57
#
# Best score in memory: 0.57
#
# Best score in memory: 0.70
#
# Best score in memory: 0.70
#
# Best score in memory: 0.70
#
# Best score in memory: 0.70
#
# Best score in memory: 0.70
#
# Best score in memory: 0.70
#
# Best score in memory: 0.70
#
# Best score in memory: 0.70
#
# Best score in memory: 0.70
#
# Best score in memory: 0.70
#
# Best score in memory: 0.70
#
# Best score in memory: 0.70
#
# Best score in memory: 0.70
#
# Best score in memory: 0.70
#
# Best score in memory: 0.70
#
# Best score in memory: 0.70
#
# Best score in memory: 0.70
#
# Best score in memory: 0.70
#
# Best score in memory: 0.70
#
# Best score in memory: 0.70
#
# Best score in memory: 0.70
#
# Best score in memory: 0.70
#
# Best score in memory: 0.70
#
# Best score in memory: 0.72
#
# Best score in memory: 0.72
#
# Best score in memory: 0.72
#
# Best score in memory: 0.72
#
# Best score in memory: 0.72
#
# Best score in memory: 0.72
#
# Best score in memory: 0.72
#
# Best score in memory: 0.72
#
# Best score in memory: 0.72
#
# Best score in memory: 0.72
#
# Best score in memory: 0.72
#
# Best score in memory: 0.72
#
# Best score in memory: 0.72
#
# Best score in memory: 0.72
#
# Best score in memory: 0.72
#
# Best score in memory: 0.72
#
# Best score in memory: 0.72
#
# Best score in memory: 0.72
#
# Best score in memory: 0.72
#
# Best score in memory: 0.72
#
# Best score in memory: 0.72
#
# Best score in memory: 0.72
#
# Best score in memory: 0.72
#
# Best score in memory: 0.72
#
# Best score in memory: 0.72
#
# Best score in memory: 0.72
#
# Best score in memory: 0.72
#
# Best score in memory: 0.72
#
# Best score in memory: 0.72
#
# Best score in memory: 0.79
#
# Best score in memory: 0.79
#
# Best score in memory: 0.79
#
# Best score in memory: 0.79
#
# Best score in memory: 0.79
#
# Best score in memory: 0.81
#
# Best score in memory: 0.83
#
# Best score in memory: 0.83
#
# Best score in memory: 0.83
#
# Best score in memory: 0.83
#
# Best score in memory: 0.83
#
# Best score in memory: 0.83
#
# Best score in memory: 0.83
#
# Best score in memory: 0.83
#
# Best score in memory: 0.83
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# Best score in memory: 1.00
#
# ********************************************************************************
#
#          Best recorded SMILES:
#
# Score     Prior log P     SMILES
#
# 1.00   -14.05        Nc1nc2ccccc2s1
# 0.96   -16.83        Nc1nc2ccc(CCc3ccccc3)cc2s1
# 0.96   -17.39        Nc1nc2cc(CCc3ccccc3)ccc2s1
# 0.96   -19.32        Nc1nc2cc(CCCc3ccccc3)ccc2s1
# 0.95   -21.70        Nc1nc2cc(C=CC=Cc3ccccc3)ccc2s1
# 0.95   -25.21        Nc1nc2ccc(CCc3ccc(C#N)cc3)cc2s1
# 0.95   -20.39        Nc1nc2ccc(CC=Cc3ccccc3)cc2s1
# 0.95   -18.36        Nc1nc2cc(C=Cc3ccccc3)ccc2s1
# 0.94   -15.13        Nc1nc2ccc(Cc3ccccc3)cc2s1
# 0.94   -21.76        Nc1nc2ccc(CC=CCO)cc2s1
# 0.94   -21.44        Nc1nc2cc(CCCF)ccc2s1
# 0.94   -18.19        Nc1nc2cc(Cc3ccccc3)ccc2s1
# 0.94   -20.71        Nc1nc2cc(CCc3ccncc3)ccc2s1
# 0.94   -15.02        Nc1nc2ccc(Br)cc2s1
# 0.94   -18.82        Nc1nc2ccc(Cc3ccc(N)cc3)cc2s1
# 0.94   -21.88        Nc1nc2cc(CCc3cccc(O)c3)ccc2s1
# 0.94   -18.71        Nc1nc2ccc(C#CCO)cc2s1
# 0.94   -20.36        Nc1nc2cc(CCCOc3ccccc3)ccc2s1
# 0.94   -23.76        Nc1nc2ccc(CCc3cccc(OCc4ccccc4)c3)cc2s1
# 0.94   -29.46        Nc1nc2cc(CC=CCBr)ccc2s1
# 0.94   -26.17        Nc1nc2cc(CCCCCCBr)ccc2s1
# 0.94   -23.98        Nc1nc2cc(CCCBr)ccc2s1
# 0.93   -15.42        Nc1nc2ccc(N)cc2s1
# 0.93   -20.17        Nc1nc2ccc(CCNc3ccccc3)cc2s1
# 0.93   -22.22        Nc1nc2ccc(Cc3cccc(CO)c3)cc2s1
# 0.90   -18.36        Nc1nc2ccc(N=Nc3ccccc3)cc2s1
# 0.90   -25.18        Nc1nc2cc(CCCOc3ccccc3OCCO)ccc2s1
# 0.90   -33.92        Nc1nc2ccc(COc3ccc(COCCOCCOCCO)cc3)cc2s1
# 0.90   -26.70        Nc1nc2ccc(C=CNc3ccccn3)cc2s1
# 0.90   -20.70        Nc1nc2ccc(OCC=CCO)cc2s1
# 0.90   -27.33        Nc1nc2ccc(C=CC=Cc3ccccc3O)cc2s1
# 0.90   -19.97        Nc1nc2cc(CNc3ccccc3N)ccc2s1
# 0.90   -25.11        Nc1nc2c(C=CCc3ccccc3)cccc2s1
# 0.90   -15.96        Nc1nc2ccc(NCc3ccccc3)cc2s1
# 0.90   -17.65        Nc1nc2ccc(NCCc3ccccc3)cc2s1
# 0.90   -14.74        Nc1nc2cc(Cl)ccc2s1
# 0.90   -20.97        Nc1nc2cc(Cc3ccccc3F)ccc2s1
# 0.90   -19.32        Nc1nc2ccc(N=Cc3ccccc3)cc2s1
# 0.90   -20.56        Nc1nc2ccc(Cc3ccc(C(=O)O)cc3)cc2s1
# 0.90   -27.76        Nc1nc2ccc(CCOc3ccccc3C=O)cc2s1
# 0.90   -21.80        Nc1nc2ccc(CCOc3ccccc3Cl)cc2s1
# 0.90   -20.95        Nc1nc2cc(Cc3ccccn3)ccc2s1
# 0.90   -20.18        Nc1nc2ccc(C=Cc3ccccc3Cl)cc2s1
# 0.90   -29.30        Nc1nc2ccc(CCc3ccccc3CN)cc2s1
# 0.90   -21.94        Nc1nc2ccc(COc3ccc(Cl)cc3)cc2s1
# 0.90   -18.28        Nc1nc2cc(CC(=O)O)ccc2s1
# 0.90   -23.14        Nc1nc2cc(COc3ccc(Br)cc3)ccc2s1
# 0.90   -16.44        Nc1nc2c(Br)cc(Br)cc2s1
# 0.89   -23.06        Nc1nc2ccc(Cc3ncccn3)cc2s1
# 0.89   -18.02        Nc1nc2cc(-c3ccc(F)cc3)ccc2s1
# 0.89   -18.99        Nc1nc2ccc(CC(=O)NCc3ccccc3)cc2s1
# 0.89   -20.12        Nc1nc2ccc(CCNCC(O)c3ccccc3)cc2s1
# 0.89   -28.46        Nc1nc2cc(CCCOCCc3ccccc3F)ccc2s1
# 0.89   -28.78        Nc1nc2c(CCCc3cccc(F)c3)cccc2s1
# 0.89   -25.95        Nc1nc2c(CCc3cccc(F)c3)cccc2s1
# 0.89   -24.05        Nc1nc2ccc(COc3ccccc3O)cc2s1
# 0.89   -24.30        Nc1nc2cc(C=Cc3ccc(Cl)cc3Cl)ccc2s1
# 0.89   -26.28        Nc1nc2ccc(CCc3cccnc3N)cc2s1
# 0.89   -21.13        Nc1nc2cc(CC(O)CO)ccc2s1
# 0.89   -29.11        Nc1nc2cc(C=CCNCCNc3ccccc3)ccc2s1
#
# ********************************************************************************

# %%
#show result
print(f"original: {sm1}")
print(f"reconstructed: {sm2}")
# Out:
# original: c1ccc2c(c1)nc(s2)N
# reconstructed: Nc1nc2ccccc2s1
